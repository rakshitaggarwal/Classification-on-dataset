# %% [markdown]
# <a href="https://colab.research.google.com/github/rakshitaggarwal/Classification-on-dataset/blob/main/Classification_on_titanic_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pycaret &> /dev/null
print("pycaret installed successfully")
# Out:
# pycaret installed successfully

# %%
from pycaret.utils import version
version()
# Out:
# '3.0.2'

# %%
from pycaret.datasets import get_data
dataset=get_data('index')
# Out:
#                              Dataset    Data Types  \
# 0                            anomaly  Multivariate
# 1                             france  Multivariate
# 2                            germany  Multivariate
# 3                               bank  Multivariate
# 4                              blood  Multivariate
# 5                             cancer  Multivariate
# 6                             credit  Multivariate
# 7                           diabetes  Multivariate
# 8                    electrical_grid  Multivariate
# 9                           employee  Multivariate
# 10                             heart  Multivariate
# 11                     heart_disease  Multivariate
# 12                         hepatitis  Multivariate
# 13                            income  Multivariate
# 14                             juice  Multivariate
# 15                               nba  Multivariate
# 16                              wine  Multivariate
# ...

# %%
titanic_dataset=get_data("titanic") #SN is 18
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
from pycaret.classification import *
s=setup(data=titanic_dataset,target='Survived')
# Out:
# <style type="text/css">
# #T_14f33_row11_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_14f33" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_14f33_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_14f33_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_14f33_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_14f33_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_14f33_row0_col1" class="data row0 col1" >7579</td>
#     </tr>
#     <tr>
#       <th id="T_14f33_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_14f33_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_14f33_row1_col1" class="data row1 col1" >Survived</td>
#     </tr>
#     <tr>
#       <th id="T_14f33_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
cm=compare_models()
# Out:
# <style type="text/css">
# #T_20bb0 th {
#   text-align: left;
# }
# ...

# %%
setup(data=titanic_dataset,target='Survived',
      normalize=True,normalize_method='zscore')
cm=compare_models()
# Out:
# <style type="text/css">
# #T_eeece_row11_col1, #T_eeece_row17_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_eeece" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_eeece_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_eeece_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_eeece_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_eeece_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_eeece_row0_col1" class="data row0 col1" >1582</td>
#     </tr>
#     <tr>
#       <th id="T_eeece_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_eeece_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_eeece_row1_col1" class="data row1 col1" >Survived</td>
#     </tr>
#     <tr>
# ...

# %%
setup(data=titanic_dataset,target='Survived',
      feature_selection=True,feature_selection_method='classic')
cm=compare_models()
# Out:
# <style type="text/css">
# #T_d30b6_row11_col1, #T_d30b6_row17_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_d30b6" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d30b6_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_d30b6_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d30b6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d30b6_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_d30b6_row0_col1" class="data row0 col1" >8416</td>
#     </tr>
#     <tr>
#       <th id="T_d30b6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d30b6_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_d30b6_row1_col1" class="data row1 col1" >Survived</td>
#     </tr>
#     <tr>
# ...

# %%
setup(data=titanic_dataset,target='Survived',
      remove_outliers=True,outliers_threshold=0.05)
cm=compare_models()
# Out:
# <style type="text/css">
# #T_e9564_row11_col1, #T_e9564_row17_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_e9564" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e9564_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_e9564_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e9564_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e9564_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_e9564_row0_col1" class="data row0 col1" >423</td>
#     </tr>
#     <tr>
#       <th id="T_e9564_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e9564_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_e9564_row1_col1" class="data row1 col1" >Survived</td>
#     </tr>
#     <tr>
# ...

# %%
setup(data=titanic_dataset,target='Survived',
      transformation=True,transformation_method='yeo-johnson')
cm=compare_models()
# Out:
# <style type="text/css">
# #T_cfa1b_row11_col1, #T_cfa1b_row17_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_cfa1b" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cfa1b_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_cfa1b_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cfa1b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cfa1b_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_cfa1b_row0_col1" class="data row0 col1" >3791</td>
#     </tr>
#     <tr>
#       <th id="T_cfa1b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_cfa1b_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_cfa1b_row1_col1" class="data row1 col1" >Survived</td>
#     </tr>
#     <tr>
# ...

# %%
setup(data=titanic_dataset,target='Survived',
      pca=True,pca_method='linear')
cm=compare_models()
# Out:
# <style type="text/css">
# #T_85437_row11_col1, #T_85437_row17_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_85437" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_85437_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_85437_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_85437_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_85437_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_85437_row0_col1" class="data row0 col1" >3632</td>
#     </tr>
#     <tr>
#       <th id="T_85437_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_85437_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_85437_row1_col1" class="data row1 col1" >Survived</td>
#     </tr>
#     <tr>
# ...

# %%
setup(data=titanic_dataset,target='Survived',
      remove_outliers=True,outliers_threshold=0.05,
      normalize=True,normalize_method='zscore',
      transformation=True,transformation_method='yeo-johnson')
cm=compare_models()
# Out:
# <style type="text/css">
# #T_5d288_row11_col1, #T_5d288_row17_col1, #T_5d288_row19_col1, #T_5d288_row21_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_5d288" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5d288_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_5d288_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5d288_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5d288_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_5d288_row0_col1" class="data row0 col1" >7409</td>
#     </tr>
#     <tr>
#       <th id="T_5d288_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5d288_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_5d288_row1_col1" class="data row1 col1" >Survived</td>
#     </tr>
#     <tr>
# ...

# %%
from pycaret.datasets import get_data
from pycaret.classification import *
titanic_dataset=get_data('titanic')
setup(data=titanic_dataset,target='Survived')
rf_model=create_model('rf')
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# ...

# %%
new_dataset=get_data("titanic").iloc[:10]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
new_predictions=predict_model(rf_model,data=new_dataset)
new_predictions
# Out:
# <style type="text/css">
# </style>
# <table id="T_ae65c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ae65c_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_ae65c_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_ae65c_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_ae65c_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_ae65c_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_ae65c_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_ae65c_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_ae65c_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ae65c_level0_row0" class="row_heading level0 row0" >0</th>
# ...

# %%
new_predictions.to_csv("new_predictions.csv",index=False)
from google.colab import files
files.download("new_predictions.csv")

# %%
sm=save_model(rf_model,'rf_modelFile')
# Out:
# Transformation Pipeline and Model Successfully Saved

# %%
from google.colab import files
files.download('rf_modelFile.pkl')

# %%
#create confusion matrix...
plot_model(rf_model,plot='confusion_matrix')

# %%
#plot learning curve
plot_model(rf_model,plot='learning')

# %%
#plot AUC curve
plot_model(rf_model,plot='auc')

# %%
#plot decision boundary curve
plot_model(rf_model,plot='boundary')

# %%
#get model parameters
plot_model(rf_model,plot='parameter')
# Out:
#                          Parameters
# bootstrap                      True
# ccp_alpha                       0.0
# class_weight                   None
# criterion                      gini
# max_depth                      None
# max_features                   sqrt
# max_leaf_nodes                 None
# max_samples                    None
# min_impurity_decrease           0.0
# min_samples_leaf                  1
# min_samples_split                 2
# min_weight_fraction_leaf        0.0
# n_estimators                    100
# n_jobs                           -1
# oob_score                     False
# random_state                   6629
# verbose                           0
# warm_start                    False

# %%
plot_model(rf_model,plot='feature')

# %%
rf_modelTuned=tune_model(rf_model,n_iter=5)
# Out:
# <style type="text/css">
# #T_bc91e_row10_col0, #T_bc91e_row10_col1, #T_bc91e_row10_col2, #T_bc91e_row10_col3, #T_bc91e_row10_col4, #T_bc91e_row10_col5, #T_bc91e_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_bc91e" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bc91e_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_bc91e_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_bc91e_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_bc91e_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_bc91e_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_bc91e_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_bc91e_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
# ...

# %% [markdown]
#  tuning a model improves its performance, enhances generalization, mitigates overfitting and underfitting, optimizes resource utilization, and provides a deeper understanding of the model's behavior. These benefits collectively contribute to building more accurate and effective machine learning models.

# %%
#getting paramters of tuned model..
plot_model(rf_model,plot='parameter')
# Out:
#                          Parameters
# bootstrap                      True
# ccp_alpha                       0.0
# class_weight                   None
# criterion                      gini
# max_depth                      None
# max_features                   sqrt
# max_leaf_nodes                 None
# max_samples                    None
# min_impurity_decrease           0.0
# min_samples_leaf                  1
# min_samples_split                 2
# min_weight_fraction_leaf        0.0
# n_estimators                    100
# n_jobs                           -1
# oob_score                     False
# random_state                   6629
# verbose                           0
# warm_start                    False
